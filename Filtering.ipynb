# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import string

# %%
artistLyricsDF = pd.read_csv('lyrics_all_combined.csv')
#artistLyricsDF.head()
#artistLyricsDF.info()

tcc_lyrics = pd.read_csv('tcc_ceds_music.csv')
tcc_lyrics.info()
tcc_lyrics.head()
tcc_lyrics.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28372 entries, 0 to 28371
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28372 non-null  int64
#  1   artist_name               28372 non-null  object
#  2   track_name                28372 non-null  object
#  3   release_date              28372 non-null  int64
#  4   genre                     28372 non-null  object
#  5   lyrics                    28372 non-null  object
#  6   len                       28372 non-null  int64
#  7   dating                    28372 non-null  float64
#  8   violence                  28372 non-null  float64
#  9   world/life                28372 non-null  float64
#  10  night/time                28372 non-null  float64
#  11  shake the audience        28372 non-null  float64
#  12  family/gospel             28372 non-null  float64
# ...

# %%
tcc_lyrics.genre.value_counts().plot.bar(rot=0)
tcc_lyrics
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
rocks = tcc_lyrics[tcc_lyrics['genre']=='jazz']
print("f",rocks.shape)
rocks = rocks[rocks['len']>=55]
rocks.drop(columns=['Unnamed: 0','len', 'dating', 'violence', 'world/life', 'night/time',
       'shake the audience', 'family/gospel', 'romantic', 'communication',
      'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
       'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy','obscene','music','movement/places','light/visual perceptions',
       'topic', 'age'],inplace=True,axis=1)
print('l',rocks.shape)
rocks.head(25)
rocks.to_csv('jazz.csv')
# Out:
# f (3845, 31)
# l (2109, 5)

# %%
rocks = tcc_lyrics[tcc_lyrics['genre']=='pop']
print("f",rocks.shape)
rocks = rocks[rocks['len']>=55]
rocks.drop(columns=['Unnamed: 0','len', 'dating', 'violence', 'world/life', 'night/time',
       'shake the audience', 'family/gospel', 'romantic', 'communication',
      'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
       'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy','obscene','music','movement/places','light/visual perceptions',
       'topic', 'age'],inplace=True,axis=1)
print('l',rocks.shape)
rocks.head(25)
rocks.to_csv('pop.csv')
# Out:
# f (7042, 31)
# l (4617, 5)

# %%
blues = tcc_lyrics[tcc_lyrics['genre']=='blues']
print("f",blues.shape)
blues = blues[blues['len']>=55]
blues.drop(columns=['Unnamed: 0','len', 'dating', 'violence', 'world/life', 'night/time',
       'shake the audience', 'family/gospel', 'romantic', 'communication',
      'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
       'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy','obscene','music','movement/places','light/visual perceptions',
       'topic', 'age'],inplace=True,axis=1)
print('l',blues.shape)
blues.head(25)
blues.to_csv('blues.csv')
# Out:
# f (4604, 31)
# l (2432, 5)

# %%
artistLyricsDF.genre.value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
aldf = artistLyricsDF[['artist_name', 'track_name', 'lyrics', 'genre']]
aldf.info()

finalDF = aldf[aldf.lyrics.notnull()]
finalDF.info()

artists = finalDF['artist_name'].unique()
genres = finalDF['genre'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7633 entries, 0 to 7632
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  7633 non-null   object
#  1   track_name   7633 non-null   object
#  2   lyrics       7628 non-null   object
#  3   genre        7633 non-null   object
# dtypes: object(4)
# memory usage: 238.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7628 entries, 0 to 7632
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  7628 non-null   object
#  1   track_name   7628 non-null   object
#  2   lyrics       7628 non-null   object
#  3   genre        7628 non-null   object
# dtypes: object(4)
# memory usage: 298.0+ KB

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='genre', data=finalDF)

plt.title('Song Count by Genre in All Languages')
plt.ylabel('Number of Songs', fontsize=12)
plt.xlabel('Genre', fontsize=12)
plt.show()

# %%
genreLabels=[]

for x in finalDF['genre'].tolist():
    if x == 'blues':
        y = True
    else:
        y = False
    genreLabels.append(y)

is_blues = np.array(genreLabels)

# %%
finalDF.rename(columns = {'artist_name':'Artist', 'track_name':'SName','genre':'Genre',''}, inplace = True)

Artists = finalDF['Artist'].unique()
Genres = finalDF['Genre'].unique()

df = pd.DataFrame(columns=('artist', 'words', 'songcount'))
j=0

tokens =[]
for artist in Artists:
    num_words = 0
    lyrics = finalDF['Lyric'][englishDF['Artist'] == artist]
    #print("\nArtist %s" %artist, "Num Lyrics %s" %len(lyrics))
    for lyric in lyrics:
        #print("\nArtist %s" %artist,"Lyric:\n" , lyric)
        words = simple_tokenizer(lyric)
        tokens.append(words)
        num_words = num_words + len(words)
    df.loc[j] = (artist, num_words, len(lyrics))
    j+=1
    i=0
